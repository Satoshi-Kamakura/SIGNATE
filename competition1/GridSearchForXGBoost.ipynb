# %% [markdown]
# ## GridSearchでXGBoostのパラメタを決める

# %%
import pandas as pd
import numpy as np
# GridSearch
from sklearn.model_selection import GridSearchCV 
from sklearn.metrics.scorer import make_scorer
# XGBoost
import xgboost as xgb
from xgboost import XGBRegressor
from xgboost import XGBClassifier
# Time
import time

# %%
# 評価指標をコンテストで提示されているMean Absolute Percentage Errorにする
def mape( y_train: np.array, y_pred: np.array):
    diff = 0
    n = len(y_train)
    for i in range(n):
        diff += abs(y_train[i]-y_pred[i])/y_train[i]
    score = 100*diff / n
    
    return score

# %%
train_x = pd.read_csv("data/processed_train_goto_x_v7.csv").drop(['id','pj_no'],axis=1)
train_y = pd.read_csv("data/processed_train_goto_y_v7.csv").drop(['id'], axis=1)

# %%
params = {
    'gamma':0.1
}

target_params={
    'n_estimators':[300,500,700,900],
#    'max_depth':[3,4,5],
#    'min_child_weight':[1,2,3]

}

#    'gamma':[0.0,0.1,0.2],
#   'subsample':[0.5,0.6,0.7,0.8,0.9,1.0]
#    'colsample_bytree':[0.6,0.7,0.8,0.9,1.0],
#    'learning_rate':[0.5, 0.2, 0.1, 0.05]

# %%
my_scorer = make_scorer(mape, greater_is_better=False)
gs = GridSearchCV(estimator = XGBRegressor(**params,seed=42),param_grid=target_params, cv=5,n_jobs=-1, scoring=my_scorer,verbose=3)
s = time.perf_counter()
gs.fit(train_x, train_y.values.ravel())
print(f"Best Parameters: {gs.best_params_}")
print(f"Best Score: {gs.best_score_}")
e = time.perf_counter()-s
print(f"elapsed time:  {e}")
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] n_estimators=300 ................................................
# [CV] n_estimators=300 ................................................
# [CV] n_estimators=300 ................................................
# [CV] n_estimators=300 ................................................
# len = 1292,   score = 10.897652659275787
# len = 1293,   score = 10.321258166846661
# len = 1292,   score = 10.553984789337013
# len = 5169,   score = 7.724359170756811
# [CV] ...... n_estimators=300, score=-10.897652659275787, total=  32.8s
# len = 5168,   score = 7.828255352860683
# [CV] ...... n_estimators=300, score=-10.321258166846661, total=  32.8s
# [CV] n_estimators=300 ................................................
# [CV] n_estimators=500 ................................................
# len = 1292,   score = 12.888711824183753
# len = 5169,   score = 7.582416291936954
# [CV] ...... n_estimators=300, score=-10.553984789337013, total=  32.8s
# [CV] n_estimators=500 ................................................
# len = 5169,   score = 7.326733086639784
# [CV] ...... n_estimators=300, score=-12.888711824183753, total=  33.0s
# [CV] n_estimators=500 ................................................
# len = 1292,   score = 11.41484915108662
# len = 5169,   score = 7.616412885109712
# [CV] ....... n_estimators=300, score=-11.41484915108662, total=  33.8s
# [CV] n_estimators=500 ................................................
# len = 1293,   score = 10.28051184135713
# len = 1292,   score = 10.539767343171834
# len = 5168,   score = 6.927473364991198
# [CV] ....... n_estimators=500, score=-10.28051184135713, total=  56.4s
# len = 1292,   score = 10.89324457607987
# [CV] n_estimators=500 ................................................
# len = 5169,   score = 6.6271634416317164
# [CV] ...... n_estimators=500, score=-10.539767343171834, total=  56.1s
# [CV] n_estimators=700 ................................................
# len = 5169,   score = 6.836337426154289
# [CV] ....... n_estimators=500, score=-10.89324457607987, total=  56.6s
# [CV] n_estimators=700 ................................................
# len = 1292,   score = 12.63728793533475
# len = 5169,   score = 6.510362078359133
# [CV] ....... n_estimators=500, score=-12.63728793533475, total=  53.7s
# [CV] n_estimators=700 ................................................
# len = 1292,   score = 11.390769543492334
# len = 5169,   score = 6.726769104202031
# [CV] ...... n_estimators=500, score=-11.390769543492334, total=  52.6s
# [CV] n_estimators=700 ................................................
# len = 1293,   score = 10.304729791346452
# len = 1292,   score = 10.929340915416875
# len = 5168,   score = 6.21446500859432
# [CV] ...... n_estimators=700, score=-10.304729791346452, total= 1.2min
# [CV] n_estimators=700 ................................................
# len = 5169,   score = 6.192553052631541
# [CV] ...... n_estimators=700, score=-10.929340915416875, total= 1.2min
# [CV] n_estimators=900 ................................................
# len = 1292,   score = 10.56418729661796
# len = 5169,   score = 5.979934577031627
# [CV] ....... n_estimators=700, score=-10.56418729661796, total= 1.3min
# [CV] n_estimators=900 ................................................
# len = 1292,   score = 12.564218458170396
# len = 5169,   score = 5.902569245081135
# [CV] ...... n_estimators=700, score=-12.564218458170396, total= 1.3min
# [CV] n_estimators=900 ................................................
# len = 1292,   score = 11.412904609991665
# len = 5169,   score = 6.0337247719298635
# [CV] ...... n_estimators=700, score=-11.412904609991665, total= 1.3min
# [CV] n_estimators=900 ................................................
# len = 1293,   score = 10.310027782482793
# len = 5168,   score = 5.622211870154828
# [CV] ...... n_estimators=900, score=-10.310027782482793, total= 1.6min
# [CV] n_estimators=900 ................................................
# len = 1292,   score = 11.019147554280678
# len = 5169,   score = 5.623071838043911
# [CV] ...... n_estimators=900, score=-11.019147554280678, total= 1.6min
# len = 1292,   score = 10.70526693517191
# len = 5169,   score = 5.4413487953225275
# [CV] ....... n_estimators=900, score=-10.70526693517191, total= 1.5min
# len = 1292,   score = 12.539511682801866
# len = 5169,   score = 5.3954416643081515
# [CV] ...... n_estimators=900, score=-12.539511682801866, total= 1.4min
# len = 1292,   score = 11.474748770166013
# len = 5169,   score = 5.490648030180787
# [CV] ...... n_estimators=900, score=-11.474748770166013, total= 1.2min
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:  5.6min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:  5.6min finished
# Best Parameters: {'n_estimators': 500}
# Best Score: -11.148181933631413
# elapsed time:  372.0426614349999

# %%
params = {
    'n_estimators':500,
    'gamma':0.1
}

target_params={
    'max_depth':[3,4,5],
    'min_child_weight':[1,2,3],
}

#    'gamma':[0.0,0.1,0.2],
#   'subsample':[0.5,0.6,0.7,0.8,0.9,1.0]
#    'colsample_bytree':[0.6,0.7,0.8,0.9,1.0],
#    'learning_rate':[0.5, 0.2, 0.1, 0.05]

my_scorer = make_scorer(mape, greater_is_better=False)
gs = GridSearchCV(estimator = XGBRegressor(**params,seed=42),param_grid=target_params, cv=5,n_jobs=-1, scoring=my_scorer,verbose=3)
s = time.perf_counter()
gs.fit(train_x, train_y.values.ravel())
print(f"Best Parameters: {gs.best_params_}")
print(f"Best Score: {gs.best_score_}")
e = time.perf_counter()-s
print(f"elapsed time:  {e}")
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] max_depth=3, min_child_weight=1 .................................
# [CV] max_depth=3, min_child_weight=1 .................................
# [CV] max_depth=3, min_child_weight=1 .................................
# [CV] max_depth=3, min_child_weight=1 .................................
# len = 1292,   score = 10.539767343171834
# len = 1293,   score = 10.28051184135713
# len = 1292,   score = 10.89324457607987
# len = 1292,   score = 12.63728793533475
# len = 5168,   score = 6.927473364991198
# len = 5169,   score = 6.6271634416317164
# [CV]  max_depth=3, min_child_weight=1, score=-10.539767343171834, total=  46.3s
# [CV]  max_depth=3, min_child_weight=1, score=-10.28051184135713, total=  46.4s
# [CV] max_depth=3, min_child_weight=1 .................................
# [CV] max_depth=3, min_child_weight=2 .................................
# len = 5169,   score = 6.836337426154289
# [CV]  max_depth=3, min_child_weight=1, score=-10.89324457607987, total=  46.5s
# [CV] max_depth=3, min_child_weight=2 .................................
# len = 5169,   score = 6.510362078359133
# [CV]  max_depth=3, min_child_weight=1, score=-12.63728793533475, total=  46.4s
# [CV] max_depth=3, min_child_weight=2 .................................
# len = 1293,   score = 10.157175980873214
# len = 1292,   score = 11.390769543492334
# len = 1292,   score = 10.778104948497287
# len = 1292,   score = 10.624172304805143
# len = 5168,   score = 6.899799743105066
# [CV]  max_depth=3, min_child_weight=2, score=-10.157175980873214, total=  46.8s
# [CV] max_depth=3, min_child_weight=2 .................................
# len = 5169,   score = 6.726769104202031
# [CV]  max_depth=3, min_child_weight=1, score=-11.390769543492334, total=  46.9s
# [CV] max_depth=3, min_child_weight=2 .................................
# len = 5169,   score = 6.854347407477228
# [CV]  max_depth=3, min_child_weight=2, score=-10.778104948497287, total=  46.8s
# [CV] max_depth=3, min_child_weight=3 .................................
# len = 5169,   score = 6.726039780401175
# [CV]  max_depth=3, min_child_weight=2, score=-10.624172304805143, total=  46.9s
# [CV] max_depth=3, min_child_weight=3 .................................
# len = 1292,   score = 11.24248550618902
# len = 1292,   score = 12.686207855117795
# len = 1293,   score = 10.349382002257443
# len = 5169,   score = 6.732678560922154
# [CV]  max_depth=3, min_child_weight=2, score=-11.24248550618902, total=  48.9s
# [CV] max_depth=3, min_child_weight=3 .................................
# len = 5169,   score = 6.519906751292682
# [CV]  max_depth=3, min_child_weight=2, score=-12.686207855117795, total=  49.0s
# [CV] max_depth=3, min_child_weight=3 .................................
# len = 1292,   score = 10.901785565426865
# len = 5168,   score = 6.890493079410681
# [CV]  max_depth=3, min_child_weight=3, score=-10.349382002257443, total=  49.0s
# [CV] max_depth=3, min_child_weight=3 .................................
# len = 5169,   score = 6.849968579479768
# [CV]  max_depth=3, min_child_weight=3, score=-10.901785565426865, total=  49.3s
# [CV] max_depth=4, min_child_weight=1 .................................
# len = 1292,   score = 12.538487670613584
# len = 5169,   score = 6.514946764057517
# [CV]  max_depth=3, min_child_weight=3, score=-12.538487670613584, total=  48.7s
# [CV] max_depth=4, min_child_weight=1 .................................
# len = 1292,   score = 10.69494422751415
# len = 1292,   score = 11.14559186782912
# len = 5169,   score = 6.685348592776564
# [CV]  max_depth=3, min_child_weight=3, score=-10.69494422751415, total=  49.2s
# [CV] max_depth=4, min_child_weight=1 .................................
# len = 5169,   score = 6.679845421123098
# [CV]  max_depth=3, min_child_weight=3, score=-11.14559186782912, total=  48.9s
# [CV] max_depth=4, min_child_weight=1 .................................
# len = 1293,   score = 10.811111270409382
# len = 5168,   score = 5.161445843211107
# [CV]  max_depth=4, min_child_weight=1, score=-10.811111270409382, total= 1.1min
# [CV] max_depth=4, min_child_weight=1 .................................
# len = 1292,   score = 10.551045151391573
# len = 1292,   score = 12.42989704613054
# len = 1292,   score = 10.909344444980752
# len = 5169,   score = 4.983518015717464
# [CV]  max_depth=4, min_child_weight=1, score=-10.551045151391573, total= 1.1min
# [CV] max_depth=4, min_child_weight=2 .................................
# len = 5169,   score = 4.936474927993031
# [CV]  max_depth=4, min_child_weight=1, score=-12.42989704613054, total= 1.1min
# [CV] max_depth=4, min_child_weight=2 .................................
# len = 5169,   score = 5.145219493893418
# [CV]  max_depth=4, min_child_weight=1, score=-10.909344444980752, total= 1.1min
# [CV] max_depth=4, min_child_weight=2 .................................
# len = 1292,   score = 11.344654853905057
# len = 5169,   score = 5.021947712619226
# [CV]  max_depth=4, min_child_weight=1, score=-11.344654853905057, total= 1.1min
# [CV] max_depth=4, min_child_weight=2 .................................
# len = 1293,   score = 10.879371264833347
# len = 1292,   score = 10.93524301993691
# len = 1292,   score = 10.774366614063098
# len = 5168,   score = 5.208160141613817
# [CV]  max_depth=4, min_child_weight=2, score=-10.879371264833347, total= 1.2min
# len = 5169,   score = 5.245775569384747
# [CV]  max_depth=4, min_child_weight=2, score=-10.93524301993691, total= 1.2min
# [CV] max_depth=4, min_child_weight=2 .................................
# [CV] max_depth=4, min_child_weight=3 .................................
# len = 5169,   score = 5.052686398346177
# [CV]  max_depth=4, min_child_weight=2, score=-10.774366614063098, total= 1.2min
# [CV] max_depth=4, min_child_weight=3 .................................
# len = 1292,   score = 12.579079152767692
# len = 5169,   score = 4.903254322681514
# [CV]  max_depth=4, min_child_weight=2, score=-12.579079152767692, total= 1.2min
# [CV] max_depth=4, min_child_weight=3 .................................
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  5.8min
# len = 1292,   score = 11.220689205856862
# len = 5169,   score = 5.010060327603177
# [CV]  max_depth=4, min_child_weight=2, score=-11.220689205856862, total= 1.2min
# [CV] max_depth=4, min_child_weight=3 .................................
# len = 1292,   score = 10.711149817375151
# len = 1293,   score = 10.708706637584399
# len = 5169,   score = 5.288778438588936
# [CV]  max_depth=4, min_child_weight=3, score=-10.711149817375151, total= 1.2min
# [CV] max_depth=4, min_child_weight=3 .................................
# len = 5168,   score = 5.153738652879293
# [CV]  max_depth=4, min_child_weight=3, score=-10.708706637584399, total= 1.2min
# [CV] max_depth=5, min_child_weight=1 .................................
# len = 1292,   score = 10.702782078337865
# len = 5169,   score = 4.999154524041156
# [CV]  max_depth=4, min_child_weight=3, score=-10.702782078337865, total= 1.2min
# [CV] max_depth=5, min_child_weight=1 .................................
# len = 1292,   score = 12.395446388770232
# len = 5169,   score = 4.931673820069916
# [CV]  max_depth=4, min_child_weight=3, score=-12.395446388770232, total= 1.2min
# [CV] max_depth=5, min_child_weight=1 .................................
# len = 1292,   score = 11.33167454725892
# len = 5169,   score = 5.085917032269725
# [CV]  max_depth=4, min_child_weight=3, score=-11.33167454725892, total= 1.2min
# [CV] max_depth=5, min_child_weight=1 .................................
# len = 1293,   score = 10.73745179953078
# len = 5168,   score = 3.644531300137062
# [CV]  max_depth=5, min_child_weight=1, score=-10.73745179953078, total= 1.4min
# [CV] max_depth=5, min_child_weight=1 .................................
# len = 1292,   score = 11.19398252827442
# len = 5169,   score = 3.705365171410711
# [CV]  max_depth=5, min_child_weight=1, score=-11.19398252827442, total= 1.4min
# [CV] max_depth=5, min_child_weight=2 .................................
# len = 1292,   score = 10.710680890237901
# len = 1292,   score = 12.92954087702041
# len = 5169,   score = 3.533077025010413
# [CV]  max_depth=5, min_child_weight=1, score=-10.710680890237901, total= 1.3min
# [CV] max_depth=5, min_child_weight=2 .................................
# len = 5169,   score = 3.452905996734047
# [CV]  max_depth=5, min_child_weight=1, score=-12.92954087702041, total= 1.3min
# [CV] max_depth=5, min_child_weight=2 .................................
# len = 1292,   score = 11.526873904820764
# len = 5169,   score = 3.5448617750892413
# [CV]  max_depth=5, min_child_weight=1, score=-11.526873904820764, total= 1.4min
# [CV] max_depth=5, min_child_weight=2 .................................
# len = 1293,   score = 10.801505110391712
# len = 5168,   score = 3.650185962390318
# [CV]  max_depth=5, min_child_weight=2, score=-10.801505110391712, total= 1.3min
# [CV] max_depth=5, min_child_weight=2 .................................
# len = 1292,   score = 11.109597130516295
# len = 1292,   score = 10.724307487554356
# len = 5169,   score = 3.769034589309319
# [CV]  max_depth=5, min_child_weight=2, score=-11.109597130516295, total= 1.3min
# [CV] max_depth=5, min_child_weight=3 .................................
# len = 5169,   score = 3.57829787101809
# [CV]  max_depth=5, min_child_weight=2, score=-10.724307487554356, total= 1.3min
# [CV] max_depth=5, min_child_weight=3 .................................
# len = 1292,   score = 12.582552302045036
# len = 5169,   score = 3.5744821610725306
# [CV]  max_depth=5, min_child_weight=2, score=-12.582552302045036, total= 1.3min
# [CV] max_depth=5, min_child_weight=3 .................................
# len = 1292,   score = 11.484581141939444
# len = 5169,   score = 3.479880953778423
# [CV]  max_depth=5, min_child_weight=2, score=-11.484581141939444, total= 1.4min
# [CV] max_depth=5, min_child_weight=3 .................................
# len = 1293,   score = 10.768000054037609
# len = 1292,   score = 11.029171166976603
# len = 5168,   score = 3.5608378079948215
# [CV]  max_depth=5, min_child_weight=3, score=-10.768000054037609, total= 1.4min
# [CV] max_depth=5, min_child_weight=3 .................................
# len = 5169,   score = 3.8304384583186226
# [CV]  max_depth=5, min_child_weight=3, score=-11.029171166976603, total= 1.4min
# len = 1292,   score = 10.68067249923097
# len = 5169,   score = 3.6151901753475806
# [CV]  max_depth=5, min_child_weight=3, score=-10.68067249923097, total= 1.3min
# len = 1292,   score = 12.457792395465
# len = 5169,   score = 3.52464792314792
# [CV]  max_depth=5, min_child_weight=3, score=-12.457792395465, total= 1.2min
# len = 1292,   score = 11.529164204836418
# len = 5169,   score = 3.6382725785033387
# [CV]  max_depth=5, min_child_weight=3, score=-11.529164204836418, total=  50.0s
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed: 12.8min finished
# Best Parameters: {'max_depth': 3, 'min_child_weight': 2}
# Best Score: -11.097483760616656
# elapsed time:  803.2149406080007

# %%
params = {
    'n_estimators':500,
    'max_depth':3,
    'min_child_weight':2
}

target_params={
    'gamma':[0.0,0.1,0.2],
    'subsample':[0.7,0.8,0.9,1.0]
}

#    'gamma':[0.0,0.1,0.2],
#   'subsample':[0.5,0.6,0.7,0.8,0.9,1.0]
#    'colsample_bytree':[0.6,0.7,0.8,0.9,1.0],
#    'learning_rate':[0.5, 0.2, 0.1, 0.05]

my_scorer = make_scorer(mape, greater_is_better=False)
gs = GridSearchCV(estimator = XGBRegressor(**params,seed=42),param_grid=target_params, cv=5,n_jobs=-1, scoring=my_scorer,verbose=3)
s = time.perf_counter()
gs.fit(train_x, train_y.values.ravel())
print(f"Best Parameters: {gs.best_params_}")
print(f"Best Score: {gs.best_score_}")
e = time.perf_counter()-s
print(f"elapsed time:  {e}")
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] gamma=0.0, subsample=0.7 ........................................
# [CV] gamma=0.0, subsample=0.7 ........................................
# [CV] gamma=0.0, subsample=0.7 ........................................
# [CV] gamma=0.0, subsample=0.7 ........................................
# len = 1293,   score = 10.540508342664294
# len = 1292,   score = 10.8075566859318
# len = 1292,   score = 10.611851343419808
# len = 1292,   score = 12.510752389219393
# len = 5168,   score = 6.779081393366777
# [CV]  gamma=0.0, subsample=0.7, score=-10.540508342664294, total=  43.0s
# len = 5169,   score = 6.722464658632171
# [CV]  gamma=0.0, subsample=0.7, score=-10.8075566859318, total=  42.9s
# [CV] gamma=0.0, subsample=0.7 ........................................
# [CV] gamma=0.0, subsample=0.8 ........................................
# len = 5169,   score = 6.662120915564046
# [CV]  gamma=0.0, subsample=0.7, score=-10.611851343419808, total=  43.0s
# [CV] gamma=0.0, subsample=0.8 ........................................
# len = 5169,   score = 6.2501697216090815
# [CV]  gamma=0.0, subsample=0.7, score=-12.510752389219393, total=  43.0s
# [CV] gamma=0.0, subsample=0.8 ........................................
# len = 1292,   score = 11.353300707883001
# len = 5169,   score = 6.6187859232578585
# [CV]  gamma=0.0, subsample=0.7, score=-11.353300707883001, total=  43.4s
# [CV] gamma=0.0, subsample=0.8 ........................................
# len = 1293,   score = 10.149318203621855
# len = 1292,   score = 10.630957361994883
# len = 1292,   score = 10.807437031102854
# len = 5168,   score = 6.674212924130337
# [CV]  gamma=0.0, subsample=0.8, score=-10.149318203621855, total=  44.3s
# [CV] gamma=0.0, subsample=0.8 ........................................
# len = 5169,   score = 6.652431709071278
# [CV]  gamma=0.0, subsample=0.8, score=-10.630957361994883, total=  44.2s
# [CV] gamma=0.0, subsample=0.9 ........................................
# len = 5169,   score = 6.693669076798389
# [CV]  gamma=0.0, subsample=0.8, score=-10.807437031102854, total=  44.5s
# [CV] gamma=0.0, subsample=0.9 ........................................
# len = 1292,   score = 12.532922638495142
# len = 5169,   score = 6.268801713518611
# [CV]  gamma=0.0, subsample=0.8, score=-12.532922638495142, total=  45.6s
# [CV] gamma=0.0, subsample=0.9 ........................................
# len = 1292,   score = 11.19654504430678
# len = 5169,   score = 6.544175743173278
# [CV]  gamma=0.0, subsample=0.8, score=-11.19654504430678, total=  45.9s
# [CV] gamma=0.0, subsample=0.9 ........................................
# len = 1292,   score = 10.713673464768195
# len = 1293,   score = 10.28602423352988
# len = 5169,   score = 6.665321873525337
# [CV]  gamma=0.0, subsample=0.9, score=-10.713673464768195, total=  46.8s
# [CV] gamma=0.0, subsample=0.9 ........................................
# len = 5168,   score = 6.715778895080333
# [CV]  gamma=0.0, subsample=0.9, score=-10.28602423352988, total=  47.2s
# [CV] gamma=0.0, subsample=1.0 ........................................
# len = 1292,   score = 10.721194890053104
# len = 5169,   score = 6.5247756812967745
# [CV]  gamma=0.0, subsample=0.9, score=-10.721194890053104, total=  48.4s
# [CV] gamma=0.0, subsample=1.0 ........................................
# len = 1292,   score = 12.356423250385728
# len = 5169,   score = 6.357529378736886
# [CV]  gamma=0.0, subsample=0.9, score=-12.356423250385728, total=  48.1s
# [CV] gamma=0.0, subsample=1.0 ........................................
# len = 1292,   score = 11.108216854559036
# len = 5169,   score = 6.545687264946997
# [CV]  gamma=0.0, subsample=0.9, score=-11.108216854559036, total=  47.8s
# [CV] gamma=0.0, subsample=1.0 ........................................
# len = 1293,   score = 10.157175980873214
# len = 5168,   score = 6.899799743105066
# [CV]  gamma=0.0, subsample=1.0, score=-10.157175980873214, total=  48.7s
# [CV] gamma=0.0, subsample=1.0 ........................................
# len = 1292,   score = 10.778104948497287
# len = 5169,   score = 6.854347407477228
# [CV]  gamma=0.0, subsample=1.0, score=-10.778104948497287, total=  48.8s
# [CV] gamma=0.1, subsample=0.7 ........................................
# len = 1292,   score = 10.624172304805143
# len = 5169,   score = 6.726039780401175
# [CV]  gamma=0.0, subsample=1.0, score=-10.624172304805143, total=  49.1s
# [CV] gamma=0.1, subsample=0.7 ........................................
# len = 1292,   score = 12.686207855117795
# len = 5169,   score = 6.519906751292682
# [CV]  gamma=0.0, subsample=1.0, score=-12.686207855117795, total=  48.8s
# [CV] gamma=0.1, subsample=0.7 ........................................
# len = 1292,   score = 11.24248550618902
# len = 5169,   score = 6.732678560922154
# [CV]  gamma=0.0, subsample=1.0, score=-11.24248550618902, total=  48.9s
# [CV] gamma=0.1, subsample=0.7 ........................................
# len = 1293,   score = 10.540508342664294
# len = 5168,   score = 6.779081393366777
# [CV]  gamma=0.1, subsample=0.7, score=-10.540508342664294, total=  44.6s
# [CV] gamma=0.1, subsample=0.7 ........................................
# len = 1292,   score = 10.8075566859318
# len = 5169,   score = 6.722464658632171
# [CV]  gamma=0.1, subsample=0.7, score=-10.8075566859318, total=  44.5s
# [CV] gamma=0.1, subsample=0.8 ........................................
# len = 1292,   score = 10.611851343419808
# len = 5169,   score = 6.662120915564046
# [CV]  gamma=0.1, subsample=0.7, score=-10.611851343419808, total=  44.6s
# [CV] gamma=0.1, subsample=0.8 ........................................
# len = 1292,   score = 12.510752389219393
# len = 5169,   score = 6.2501697216090815
# [CV]  gamma=0.1, subsample=0.7, score=-12.510752389219393, total=  44.7s
# [CV] gamma=0.1, subsample=0.8 ........................................
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  4.7min
# len = 1292,   score = 11.353300707883001
# len = 5169,   score = 6.6187859232578585
# [CV]  gamma=0.1, subsample=0.7, score=-11.353300707883001, total=  45.7s
# [CV] gamma=0.1, subsample=0.8 ........................................
# len = 1293,   score = 10.149318203621855
# len = 5168,   score = 6.674212924130337
# [CV]  gamma=0.1, subsample=0.8, score=-10.149318203621855, total=  46.9s
# [CV] gamma=0.1, subsample=0.8 ........................................
# len = 1292,   score = 10.807437031102854
# len = 5169,   score = 6.693669076798389
# [CV]  gamma=0.1, subsample=0.8, score=-10.807437031102854, total=  47.0s
# [CV] gamma=0.1, subsample=0.9 ........................................
# len = 1292,   score = 10.630957361994883
# len = 5169,   score = 6.652431709071278
# [CV]  gamma=0.1, subsample=0.8, score=-10.630957361994883, total=  47.1s
# [CV] gamma=0.1, subsample=0.9 ........................................
# len = 1292,   score = 12.532922638495142
# len = 5169,   score = 6.268801713518611
# [CV]  gamma=0.1, subsample=0.8, score=-12.532922638495142, total=  51.5s
# [CV] gamma=0.1, subsample=0.9 ........................................
# len = 1292,   score = 11.19654504430678
# len = 5169,   score = 6.544175743173278
# [CV]  gamma=0.1, subsample=0.8, score=-11.19654504430678, total=  51.2s
# [CV] gamma=0.1, subsample=0.9 ........................................
# len = 1293,   score = 10.28602423352988
# len = 5168,   score = 6.715778895080333
# [CV]  gamma=0.1, subsample=0.9, score=-10.28602423352988, total=  52.7s
# [CV] gamma=0.1, subsample=0.9 ........................................
# len = 1292,   score = 10.713673464768195
# len = 5169,   score = 6.665321873525337
# [CV]  gamma=0.1, subsample=0.9, score=-10.713673464768195, total=  52.6s
# [CV] gamma=0.1, subsample=1.0 ........................................
# len = 1292,   score = 10.721194890053104
# len = 5169,   score = 6.5247756812967745
# [CV]  gamma=0.1, subsample=0.9, score=-10.721194890053104, total=  48.6s
# [CV] gamma=0.1, subsample=1.0 ........................................
# len = 1292,   score = 12.356423250385728
# len = 5169,   score = 6.357529378736886
# [CV]  gamma=0.1, subsample=0.9, score=-12.356423250385728, total=  48.4s
# [CV] gamma=0.1, subsample=1.0 ........................................
# len = 1292,   score = 11.108216854559036
# len = 5169,   score = 6.545687264946997
# [CV]  gamma=0.1, subsample=0.9, score=-11.108216854559036, total=  48.3s
# [CV] gamma=0.1, subsample=1.0 ........................................
# len = 1293,   score = 10.157175980873214
# len = 5168,   score = 6.899799743105066
# [CV]  gamma=0.1, subsample=1.0, score=-10.157175980873214, total=  49.0s
# [CV] gamma=0.1, subsample=1.0 ........................................
# len = 1292,   score = 10.778104948497287
# len = 5169,   score = 6.854347407477228
# [CV]  gamma=0.1, subsample=1.0, score=-10.778104948497287, total=  49.3s
# [CV] gamma=0.2, subsample=0.7 ........................................
# len = 1292,   score = 10.624172304805143
# len = 5169,   score = 6.726039780401175
# [CV]  gamma=0.1, subsample=1.0, score=-10.624172304805143, total=  49.3s
# [CV] gamma=0.2, subsample=0.7 ........................................
# len = 1292,   score = 12.686207855117795
# len = 5169,   score = 6.519906751292682
# [CV]  gamma=0.1, subsample=1.0, score=-12.686207855117795, total=  49.2s
# [CV] gamma=0.2, subsample=0.7 ........................................
# len = 1292,   score = 11.24248550618902
# len = 5169,   score = 6.732678560922154
# [CV]  gamma=0.1, subsample=1.0, score=-11.24248550618902, total=  49.3s
# [CV] gamma=0.2, subsample=0.7 ........................................
# len = 1293,   score = 10.540508342664294
# len = 5168,   score = 6.779081393366777
# [CV]  gamma=0.2, subsample=0.7, score=-10.540508342664294, total=  45.1s
# [CV] gamma=0.2, subsample=0.7 ........................................
# len = 1292,   score = 10.8075566859318
# len = 5169,   score = 6.722464658632171
# [CV]  gamma=0.2, subsample=0.7, score=-10.8075566859318, total=  45.2s
# [CV] gamma=0.2, subsample=0.8 ........................................
# len = 1292,   score = 10.611851343419808
# len = 5169,   score = 6.662120915564046
# [CV]  gamma=0.2, subsample=0.7, score=-10.611851343419808, total=  45.1s
# [CV] gamma=0.2, subsample=0.8 ........................................
# len = 1292,   score = 12.510752389219393
# len = 5169,   score = 6.2501697216090815
# [CV]  gamma=0.2, subsample=0.7, score=-12.510752389219393, total=  45.4s
# [CV] gamma=0.2, subsample=0.8 ........................................
# len = 1292,   score = 11.353300707883001
# len = 5169,   score = 6.6187859232578585
# [CV]  gamma=0.2, subsample=0.7, score=-11.353300707883001, total=  45.4s
# [CV] gamma=0.2, subsample=0.8 ........................................
# len = 1293,   score = 10.149318203621855
# len = 5168,   score = 6.674212924130337
# [CV]  gamma=0.2, subsample=0.8, score=-10.149318203621855, total=  46.8s
# [CV] gamma=0.2, subsample=0.8 ........................................
# len = 1292,   score = 10.807437031102854
# len = 5169,   score = 6.693669076798389
# [CV]  gamma=0.2, subsample=0.8, score=-10.807437031102854, total=  46.6s
# [CV] gamma=0.2, subsample=0.9 ........................................
# len = 1292,   score = 10.630957361994883
# len = 5169,   score = 6.652431709071278
# [CV]  gamma=0.2, subsample=0.8, score=-10.630957361994883, total=  46.4s
# [CV] gamma=0.2, subsample=0.9 ........................................
# len = 1292,   score = 12.532922638495142
# len = 5169,   score = 6.268801713518611
# [CV]  gamma=0.2, subsample=0.8, score=-12.532922638495142, total=  46.9s
# [CV] gamma=0.2, subsample=0.9 ........................................
# len = 1292,   score = 11.19654504430678
# len = 5169,   score = 6.544175743173278
# [CV]  gamma=0.2, subsample=0.8, score=-11.19654504430678, total=  46.8s
# [CV] gamma=0.2, subsample=0.9 ........................................
# len = 1293,   score = 10.28602423352988
# len = 5168,   score = 6.715778895080333
# [CV]  gamma=0.2, subsample=0.9, score=-10.28602423352988, total=  48.4s
# [CV] gamma=0.2, subsample=0.9 ........................................
# len = 1292,   score = 10.713673464768195
# len = 5169,   score = 6.665321873525337
# [CV]  gamma=0.2, subsample=0.9, score=-10.713673464768195, total=  48.6s
# [CV] gamma=0.2, subsample=1.0 ........................................
# len = 1292,   score = 10.721194890053104
# len = 5169,   score = 6.5247756812967745
# [CV]  gamma=0.2, subsample=0.9, score=-10.721194890053104, total=  50.7s
# [CV] gamma=0.2, subsample=1.0 ........................................
# len = 1292,   score = 12.356423250385728
# len = 5169,   score = 6.357529378736886
# [CV]  gamma=0.2, subsample=0.9, score=-12.356423250385728, total=  51.7s
# [CV] gamma=0.2, subsample=1.0 ........................................
# len = 1292,   score = 11.108216854559036
# len = 5169,   score = 6.545687264946997
# [CV]  gamma=0.2, subsample=0.9, score=-11.108216854559036, total=  51.7s
# [CV] gamma=0.2, subsample=1.0 ........................................
# len = 1293,   score = 10.157175980873214
# len = 5168,   score = 6.899799743105066
# [CV]  gamma=0.2, subsample=1.0, score=-10.157175980873214, total=  52.7s
# [CV] gamma=0.2, subsample=1.0 ........................................
# len = 1292,   score = 10.778104948497287
# len = 5169,   score = 6.854347407477228
# [CV]  gamma=0.2, subsample=1.0, score=-10.778104948497287, total=  55.1s
# len = 1292,   score = 10.624172304805143
# len = 5169,   score = 6.726039780401175
# [CV]  gamma=0.2, subsample=1.0, score=-10.624172304805143, total=  54.1s
# len = 1292,   score = 12.686207855117795
# len = 5169,   score = 6.519906751292682
# [CV]  gamma=0.2, subsample=1.0, score=-12.686207855117795, total=  53.2s
# len = 1292,   score = 11.24248550618902
# len = 5169,   score = 6.732678560922154
# [CV]  gamma=0.2, subsample=1.0, score=-11.24248550618902, total=  52.2s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed: 12.1min finished
# Best Parameters: {'gamma': 0.0, 'subsample': 0.9}
# Best Score: -11.03699029004363
# elapsed time:  764.6176496519984

# %%
params = {
    'n_estimators':500,
    'max_depth':3,
    'min_child_weight':2,
    'gamma':0.0,
    'subsample':0.9
}

target_params={
    'colsample_bytree':[0.6,0.7,0.8,0.9,1.0],
    'learning_rate':[0.5, 0.2, 0.1, 0.05]
}

#    'gamma':[0.0,0.1,0.2],
#   'subsample':[0.5,0.6,0.7,0.8,0.9,1.0]


my_scorer = make_scorer(mape, greater_is_better=False)
gs = GridSearchCV(estimator = XGBRegressor(**params,seed=42),param_grid=target_params, cv=5,n_jobs=-1, scoring=my_scorer,verbose=3)
s = time.perf_counter()
gs.fit(train_x, train_y.values.ravel())
print(f"Best Parameters: {gs.best_params_}")
print(f"Best Score: {gs.best_score_}")
e = time.perf_counter()-s
print(f"elapsed time:  {e}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] colsample_bytree=0.6, learning_rate=0.5 .........................
# [CV] colsample_bytree=0.6, learning_rate=0.5 .........................
# [CV] colsample_bytree=0.6, learning_rate=0.5 .........................
# [CV] colsample_bytree=0.6, learning_rate=0.5 .........................
# len = 1293,   score = 12.215149192871975
# len = 1292,   score = 12.11466145862557
# len = 1292,   score = 13.757768497249035
# len = 1292,   score = 12.233814231007987
# len = 5168,   score = 3.7737548027039063
# [CV]  colsample_bytree=0.6, learning_rate=0.5, score=-12.215149192871975, total=  28.0s
# [CV] colsample_bytree=0.6, learning_rate=0.5 .........................
# len = 5169,   score = 3.6353517157957818
# [CV]  colsample_bytree=0.6, learning_rate=0.5, score=-12.11466145862557, total=  28.0s
# len = 5169,   score = 3.663752448242737
# [CV]  colsample_bytree=0.6, learning_rate=0.5, score=-13.757768497249035, total=  28.0s
# [CV] colsample_bytree=0.6, learning_rate=0.2 .........................
# [CV] colsample_bytree=0.6, learning_rate=0.2 .........................
# len = 5169,   score = 3.886047219905314
# [CV]  colsample_bytree=0.6, learning_rate=0.5, score=-12.233814231007987, total=  28.2s
# [CV] colsample_bytree=0.6, learning_rate=0.2 .........................
# len = 1292,   score = 12.245377874552092
# len = 1293,   score = 10.923897372672137
# len = 1292,   score = 10.966487515333682
# len = 5169,   score = 3.7937994803344326
# [CV]  colsample_bytree=0.6, learning_rate=0.5, score=-12.245377874552092, total=  28.3s
# len = 1292,   score = 10.980642267983585
# [CV] colsample_bytree=0.6, learning_rate=0.2 .........................
# len = 5168,   score = 5.485648785123171
# [CV]  colsample_bytree=0.6, learning_rate=0.2, score=-10.923897372672137, total=  28.3s
# [CV] colsample_bytree=0.6, learning_rate=0.2 .........................
# len = 5169,   score = 5.518327422895888
# [CV]  colsample_bytree=0.6, learning_rate=0.2, score=-10.966487515333682, total=  28.3s
# [CV] colsample_bytree=0.6, learning_rate=0.1 .........................
# len = 5169,   score = 5.363987754232569
# [CV]  colsample_bytree=0.6, learning_rate=0.2, score=-10.980642267983585, total=  28.3s
# [CV] colsample_bytree=0.6, learning_rate=0.1 .........................
# len = 1292,   score = 12.586849805839273
# len = 1293,   score = 10.320598772354618
# len = 1292,   score = 11.197642489986023
# len = 1292,   score = 10.734411484785415
# len = 5169,   score = 5.201702320924737
# [CV]  colsample_bytree=0.6, learning_rate=0.2, score=-12.586849805839273, total=  29.2s
# [CV] colsample_bytree=0.6, learning_rate=0.1 .........................
# len = 5168,   score = 6.766166456600653
# [CV]  colsample_bytree=0.6, learning_rate=0.1, score=-10.320598772354618, total=  29.1s
# [CV] colsample_bytree=0.6, learning_rate=0.1 .........................
# len = 5169,   score = 5.311590285677273
# [CV]  colsample_bytree=0.6, learning_rate=0.2, score=-11.197642489986023, total=  29.2s
# [CV] colsample_bytree=0.6, learning_rate=0.1 .........................
# len = 5169,   score = 6.780881151259985
# [CV]  colsample_bytree=0.6, learning_rate=0.1, score=-10.734411484785415, total=  29.1s
# [CV] colsample_bytree=0.6, learning_rate=0.05 ........................
# len = 1292,   score = 10.543827018522117
# len = 1293,   score = 10.185686541735688
# len = 1292,   score = 11.314644373572879
# len = 1292,   score = 12.337502066746099
# len = 5169,   score = 6.644740031223441
# [CV]  colsample_bytree=0.6, learning_rate=0.1, score=-10.543827018522117, total=  30.2s
# [CV] colsample_bytree=0.6, learning_rate=0.05 ........................
# len = 5168,   score = 8.0303649772134
# [CV]  colsample_bytree=0.6, learning_rate=0.05, score=-10.185686541735688, total=  29.8s
# len = 5169,   score = 6.685602783422343
# [CV]  colsample_bytree=0.6, learning_rate=0.1, score=-11.314644373572879, total=  30.0s
# [CV] colsample_bytree=0.6, learning_rate=0.05 ........................
# [CV] colsample_bytree=0.6, learning_rate=0.05 ........................
# len = 5169,   score = 6.497186540077714
# [CV]  colsample_bytree=0.6, learning_rate=0.1, score=-12.337502066746099, total=  30.2s
# [CV] colsample_bytree=0.6, learning_rate=0.05 ........................
# len = 1292,   score = 12.750192591475454
# len = 1292,   score = 10.705268511482867
# len = 1292,   score = 11.330484236176318
# len = 5169,   score = 7.5575897310868525
# [CV]  colsample_bytree=0.6, learning_rate=0.05, score=-12.750192591475454, total=  31.4s
# len = 1292,   score = 10.623064425032412
# [CV] colsample_bytree=0.7, learning_rate=0.5 .........................
# len = 5169,   score = 7.879585543803942
# [CV]  colsample_bytree=0.6, learning_rate=0.05, score=-11.330484236176318, total=  31.4s
# len = 5169,   score = 8.015385288962165
# [CV] colsample_bytree=0.7, learning_rate=0.5 .........................
# [CV]  colsample_bytree=0.6, learning_rate=0.05, score=-10.705268511482867, total=  31.6s
# [CV] colsample_bytree=0.7, learning_rate=0.5 .........................
# len = 5169,   score = 7.888367391797677
# [CV]  colsample_bytree=0.6, learning_rate=0.05, score=-10.623064425032412, total=  31.8s
# [CV] colsample_bytree=0.7, learning_rate=0.5 .........................
# len = 1292,   score = 12.319504508396012
# len = 1293,   score = 12.722843332538773
# len = 1292,   score = 12.347932713912774
# len = 5169,   score = 3.6962191091065995
# [CV]  colsample_bytree=0.7, learning_rate=0.5, score=-12.319504508396012, total=  34.4s
# [CV] colsample_bytree=0.7, learning_rate=0.5 .........................
# len = 5168,   score = 3.7391955562628305
# [CV]  colsample_bytree=0.7, learning_rate=0.5, score=-12.722843332538773, total=  34.6s
# [CV] colsample_bytree=0.7, learning_rate=0.2 .........................
# len = 1292,   score = 13.949699725497194
# len = 5169,   score = 3.7636992889111616
# [CV]  colsample_bytree=0.7, learning_rate=0.5, score=-12.347932713912774, total=  34.8s
# [CV] colsample_bytree=0.7, learning_rate=0.2 .........................
# len = 5169,   score = 3.6724276953451063
# [CV]  colsample_bytree=0.7, learning_rate=0.5, score=-13.949699725497194, total=  34.8s
# [CV] colsample_bytree=0.7, learning_rate=0.2 .........................
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  3.1min
# len = 1292,   score = 12.880071728286413
# len = 1292,   score = 11.165624583327915
# len = 1293,   score = 10.718433879358043
# len = 5169,   score = 3.6587880902724987
# len = 5168,   score = 5.445323750611631
# [CV]  colsample_bytree=0.7, learning_rate=0.2, score=-10.718433879358043, total=  35.2s
# [CV]  colsample_bytree=0.7, learning_rate=0.5, score=-12.880071728286413, total=  35.3s
# len = 5169,   score = 5.51665396265316
# [CV]  colsample_bytree=0.7, learning_rate=0.2, score=-11.165624583327915, total=  34.9s
# [CV] colsample_bytree=0.7, learning_rate=0.2 .........................
# [CV] colsample_bytree=0.7, learning_rate=0.2 .........................
# [CV] colsample_bytree=0.7, learning_rate=0.1 .........................
# len = 1292,   score = 10.854579615767745
# len = 5169,   score = 5.343253568040646
# [CV]  colsample_bytree=0.7, learning_rate=0.2, score=-10.854579615767745, total=  35.3s
# [CV] colsample_bytree=0.7, learning_rate=0.1 .........................
# len = 1292,   score = 11.23810585430318
# len = 1292,   score = 12.539675343502985
# len = 1293,   score = 10.150093226562026
# len = 5169,   score = 5.246544405045912
# [CV]  colsample_bytree=0.7, learning_rate=0.2, score=-11.23810585430318, total=  34.7s
# len = 5168,   score = 6.782122276953716
# [CV]  colsample_bytree=0.7, learning_rate=0.1, score=-10.150093226562026, total=  34.7s
# [CV] colsample_bytree=0.7, learning_rate=0.1 .........................
# [CV] colsample_bytree=0.7, learning_rate=0.1 .........................
# len = 5169,   score = 5.184622285863258
# [CV]  colsample_bytree=0.7, learning_rate=0.2, score=-12.539675343502985, total=  34.8s
# [CV] colsample_bytree=0.7, learning_rate=0.1 .........................
# len = 1292,   score = 10.833990131816778
# len = 5169,   score = 6.791454389298737
# [CV]  colsample_bytree=0.7, learning_rate=0.1, score=-10.833990131816778, total=  34.7s
# [CV] colsample_bytree=0.7, learning_rate=0.05 ........................
# len = 1292,   score = 12.57489684113971
# len = 1292,   score = 10.655432293065074
# len = 1292,   score = 11.206641911238304
# len = 5169,   score = 6.446569216184435
# [CV]  colsample_bytree=0.7, learning_rate=0.1, score=-12.57489684113971, total=  34.8s
# [CV] colsample_bytree=0.7, learning_rate=0.05 ........................
# len = 5169,   score = 6.652273450373312
# [CV]  colsample_bytree=0.7, learning_rate=0.1, score=-10.655432293065074, total=  34.9s
# [CV] colsample_bytree=0.7, learning_rate=0.05 ........................
# len = 5169,   score = 6.653741624208011
# [CV]  colsample_bytree=0.7, learning_rate=0.1, score=-11.206641911238304, total=  34.8s
# [CV] colsample_bytree=0.7, learning_rate=0.05 ........................
# len = 1293,   score = 10.209247579227226
# len = 5168,   score = 8.021891939745174
# [CV]  colsample_bytree=0.7, learning_rate=0.05, score=-10.209247579227226, total=  35.0s
# [CV] colsample_bytree=0.7, learning_rate=0.05 ........................
# len = 1292,   score = 10.645496891090911
# len = 1292,   score = 12.813958942394137
# len = 1292,   score = 10.524217940924474
# len = 5169,   score = 7.984260281304399
# [CV]  colsample_bytree=0.7, learning_rate=0.05, score=-10.645496891090911, total=  37.4s
# [CV] colsample_bytree=0.8, learning_rate=0.5 .........................
# len = 5169,   score = 7.512250779257899
# [CV]  colsample_bytree=0.7, learning_rate=0.05, score=-12.813958942394137, total=  37.3s
# [CV] colsample_bytree=0.8, learning_rate=0.5 .........................
# len = 5169,   score = 7.847156975113841
# [CV]  colsample_bytree=0.7, learning_rate=0.05, score=-10.524217940924474, total=  37.5s
# [CV] colsample_bytree=0.8, learning_rate=0.5 .........................
# len = 1292,   score = 11.283692758939223
# len = 5169,   score = 7.812782040530857
# [CV]  colsample_bytree=0.7, learning_rate=0.05, score=-11.283692758939223, total=  37.4s
# [CV] colsample_bytree=0.8, learning_rate=0.5 .........................
# len = 1293,   score = 11.662648523480899
# len = 1292,   score = 11.840827539098028
# len = 5168,   score = 3.7592872443340988
# [CV]  colsample_bytree=0.8, learning_rate=0.5, score=-11.662648523480899, total=  44.3s
# [CV] colsample_bytree=0.8, learning_rate=0.5 .........................
# len = 5169,   score = 3.905217721660465
# [CV]  colsample_bytree=0.8, learning_rate=0.5, score=-11.840827539098028, total=  44.4s
# [CV] colsample_bytree=0.8, learning_rate=0.2 .........................
# len = 1292,   score = 12.202793408184398
# len = 1292,   score = 14.053073935636371
# len = 5169,   score = 3.538287156493752
# [CV]  colsample_bytree=0.8, learning_rate=0.5, score=-12.202793408184398, total=  44.8s
# [CV] colsample_bytree=0.8, learning_rate=0.2 .........................
# len = 5169,   score = 3.582711064789003
# [CV]  colsample_bytree=0.8, learning_rate=0.5, score=-14.053073935636371, total=  44.6s
# [CV] colsample_bytree=0.8, learning_rate=0.2 .........................
# len = 1292,   score = 12.359959895319498
# len = 1293,   score = 10.653726816914373
# len = 5169,   score = 3.6317196033372827
# [CV]  colsample_bytree=0.8, learning_rate=0.5, score=-12.359959895319498, total=  44.2s
# [CV] colsample_bytree=0.8, learning_rate=0.2 .........................
# len = 5168,   score = 5.44698684763891
# [CV]  colsample_bytree=0.8, learning_rate=0.2, score=-10.653726816914373, total=  44.1s
# [CV] colsample_bytree=0.8, learning_rate=0.2 .........................
# len = 1292,   score = 10.996736745069889
# len = 1292,   score = 10.75570505378236
# len = 5169,   score = 5.423294965735238
# [CV]  colsample_bytree=0.8, learning_rate=0.2, score=-10.996736745069889, total=  44.5s
# [CV] colsample_bytree=0.8, learning_rate=0.1 .........................
# len = 5169,   score = 5.325913403972979
# [CV]  colsample_bytree=0.8, learning_rate=0.2, score=-10.75570505378236, total=  44.3s
# [CV] colsample_bytree=0.8, learning_rate=0.1 .........................
# len = 1292,   score = 12.577160038952721
# len = 1292,   score = 11.430425762197627
# len = 5169,   score = 5.042106706594373
# [CV]  colsample_bytree=0.8, learning_rate=0.2, score=-12.577160038952721, total=  45.9s
# [CV] colsample_bytree=0.8, learning_rate=0.1 .........................
# len = 5169,   score = 5.272117109775032
# [CV]  colsample_bytree=0.8, learning_rate=0.2, score=-11.430425762197627, total=  45.9s
# [CV] colsample_bytree=0.8, learning_rate=0.1 .........................
# len = 1293,   score = 10.243046270710133
# len = 1292,   score = 10.880161421984003
# len = 5168,   score = 6.760863746955806
# [CV]  colsample_bytree=0.8, learning_rate=0.1, score=-10.243046270710133, total=  45.8s
# [CV] colsample_bytree=0.8, learning_rate=0.1 .........................
# len = 5169,   score = 6.7409905041404885
# [CV]  colsample_bytree=0.8, learning_rate=0.1, score=-10.880161421984003, total=  45.9s
# [CV] colsample_bytree=0.8, learning_rate=0.05 ........................
# len = 1292,   score = 10.52916664791744
# len = 1292,   score = 12.306472841114537
# len = 5169,   score = 6.567697864212541
# [CV]  colsample_bytree=0.8, learning_rate=0.1, score=-10.52916664791744, total=  43.8s
# [CV] colsample_bytree=0.8, learning_rate=0.05 ........................
# len = 5169,   score = 6.367686164334787
# [CV]  colsample_bytree=0.8, learning_rate=0.1, score=-12.306472841114537, total=  43.7s
# [CV] colsample_bytree=0.8, learning_rate=0.05 ........................
# len = 1292,   score = 11.19310380287605
# len = 1293,   score = 10.292812376516768
# len = 5169,   score = 6.635440836346624
# [CV]  colsample_bytree=0.8, learning_rate=0.1, score=-11.19310380287605, total=  43.8s
# [CV] colsample_bytree=0.8, learning_rate=0.05 ........................
# len = 5168,   score = 7.971783596124467
# [CV]  colsample_bytree=0.8, learning_rate=0.05, score=-10.292812376516768, total=  43.6s
# [CV] colsample_bytree=0.8, learning_rate=0.05 ........................
# len = 1292,   score = 10.518567197422925
# len = 1292,   score = 10.769280566157699
# len = 5169,   score = 7.826743269967281
# [CV]  colsample_bytree=0.8, learning_rate=0.05, score=-10.518567197422925, total=  44.3s
# [CV] colsample_bytree=0.9, learning_rate=0.5 .........................
# len = 5169,   score = 7.981012782840772
# [CV]  colsample_bytree=0.8, learning_rate=0.05, score=-10.769280566157699, total=  44.5s
# [CV] colsample_bytree=0.9, learning_rate=0.5 .........................
# len = 1292,   score = 11.247813170698256
# len = 1292,   score = 12.793006783874926
# len = 5169,   score = 7.80515614126181
# [CV]  colsample_bytree=0.8, learning_rate=0.05, score=-11.247813170698256, total=  44.5s
# [CV] colsample_bytree=0.9, learning_rate=0.5 .........................
# len = 5169,   score = 7.527458547978169
# [CV]  colsample_bytree=0.8, learning_rate=0.05, score=-12.793006783874926, total=  44.7s
# [CV] colsample_bytree=0.9, learning_rate=0.5 .........................
# len = 1293,   score = 11.89818586971114
# len = 1292,   score = 12.230050257862517
# len = 5168,   score = 3.8029872359775654
# [CV]  colsample_bytree=0.9, learning_rate=0.5, score=-11.89818586971114, total=  51.4s
# [CV] colsample_bytree=0.9, learning_rate=0.5 .........................
# len = 5169,   score = 3.8995946946472495
# [CV]  colsample_bytree=0.9, learning_rate=0.5, score=-12.230050257862517, total=  51.4s
# [CV] colsample_bytree=0.9, learning_rate=0.2 .........................
# len = 1292,   score = 11.831561810594009
# len = 1292,   score = 13.03431203277547
# len = 5169,   score = 3.716052142251145
# [CV]  colsample_bytree=0.9, learning_rate=0.5, score=-11.831561810594009, total=  51.3s
# [CV] colsample_bytree=0.9, learning_rate=0.2 .........................
# len = 5169,   score = 3.4919945020259444
# [CV]  colsample_bytree=0.9, learning_rate=0.5, score=-13.03431203277547, total=  51.4s
# [CV] colsample_bytree=0.9, learning_rate=0.2 .........................
# len = 1292,   score = 13.067045356521712
# len = 1293,   score = 10.699679474638383
# len = 5169,   score = 3.6599255856934727
# [CV]  colsample_bytree=0.9, learning_rate=0.5, score=-13.067045356521712, total=  51.4s
# [CV] colsample_bytree=0.9, learning_rate=0.2 .........................
# len = 5168,   score = 5.397826500171368
# [CV]  colsample_bytree=0.9, learning_rate=0.2, score=-10.699679474638383, total=  51.3s
# [CV] colsample_bytree=0.9, learning_rate=0.2 .........................
# len = 1292,   score = 11.352049453926005
# len = 1292,   score = 10.83685979548068
# len = 5169,   score = 5.47326842661863
# [CV]  colsample_bytree=0.9, learning_rate=0.2, score=-11.352049453926005, total=  51.3s
# [CV] colsample_bytree=0.9, learning_rate=0.1 .........................
# len = 5169,   score = 5.2948138955838955
# [CV]  colsample_bytree=0.9, learning_rate=0.2, score=-10.83685979548068, total=  51.4s
# [CV] colsample_bytree=0.9, learning_rate=0.1 .........................
# len = 1292,   score = 12.732522211667833
# len = 1292,   score = 11.360798638113295
# len = 5169,   score = 5.115410235709195
# [CV]  colsample_bytree=0.9, learning_rate=0.2, score=-12.732522211667833, total=  51.1s
# [CV] colsample_bytree=0.9, learning_rate=0.1 .........................
# len = 5169,   score = 5.322358394874053
# [CV]  colsample_bytree=0.9, learning_rate=0.2, score=-11.360798638113295, total=  51.3s
# [CV] colsample_bytree=0.9, learning_rate=0.1 .........................
# len = 1293,   score = 10.388088913661633
# len = 1292,   score = 10.799412162948304
# len = 5168,   score = 6.744681880112335
# [CV]  colsample_bytree=0.9, learning_rate=0.1, score=-10.388088913661633, total=  51.0s
# [CV] colsample_bytree=0.9, learning_rate=0.1 .........................
# len = 5169,   score = 6.69906148233178
# [CV]  colsample_bytree=0.9, learning_rate=0.1, score=-10.799412162948304, total=  50.9s
# [CV] colsample_bytree=0.9, learning_rate=0.05 ........................
# len = 1292,   score = 12.43648385934219
# len = 1292,   score = 10.483580760425015
# len = 5169,   score = 6.343429954508226
# [CV]  colsample_bytree=0.9, learning_rate=0.1, score=-12.43648385934219, total=  50.8s
# [CV] colsample_bytree=0.9, learning_rate=0.05 ........................
# len = 5169,   score = 6.569953650850942
# [CV]  colsample_bytree=0.9, learning_rate=0.1, score=-10.483580760425015, total=  51.2s
# [CV] colsample_bytree=0.9, learning_rate=0.05 ........................
# len = 1292,   score = 11.351520193077047
# len = 1293,   score = 10.253187171939574
# len = 5169,   score = 6.583676783170802
# [CV]  colsample_bytree=0.9, learning_rate=0.1, score=-11.351520193077047, total=  50.9s
# [CV] colsample_bytree=0.9, learning_rate=0.05 ........................
# len = 5168,   score = 7.92683898242779
# [CV]  colsample_bytree=0.9, learning_rate=0.05, score=-10.253187171939574, total=  51.0s
# [CV] colsample_bytree=0.9, learning_rate=0.05 ........................
# len = 1292,   score = 10.466442542164357
# len = 1292,   score = 10.71723610456552
# len = 5169,   score = 7.797476484094278
# [CV]  colsample_bytree=0.9, learning_rate=0.05, score=-10.466442542164357, total=  50.6s
# [CV] colsample_bytree=1.0, learning_rate=0.5 .........................
# len = 5169,   score = 7.929232060849458
# [CV]  colsample_bytree=0.9, learning_rate=0.05, score=-10.71723610456552, total=  50.7s
# [CV] colsample_bytree=1.0, learning_rate=0.5 .........................
# len = 1292,   score = 12.710834298644105
# len = 1292,   score = 11.235274946399553
# len = 5169,   score = 7.490395186978488
# [CV]  colsample_bytree=0.9, learning_rate=0.05, score=-12.710834298644105, total=  50.8s
# [CV] colsample_bytree=1.0, learning_rate=0.5 .........................
# len = 5169,   score = 7.737760188536559
# [CV]  colsample_bytree=0.9, learning_rate=0.05, score=-11.235274946399553, total=  50.8s
# [CV] colsample_bytree=1.0, learning_rate=0.5 .........................
# len = 1293,   score = 12.04779407279724
# len = 1292,   score = 12.76594600688694
# len = 5168,   score = 3.716383583930425
# [CV]  colsample_bytree=1.0, learning_rate=0.5, score=-12.04779407279724, total=  56.2s
# [CV] colsample_bytree=1.0, learning_rate=0.5 .........................
# len = 5169,   score = 3.8030277828317187
# [CV]  colsample_bytree=1.0, learning_rate=0.5, score=-12.76594600688694, total=  56.3s
# [CV] colsample_bytree=1.0, learning_rate=0.2 .........................
# len = 1292,   score = 11.740658302874975
# len = 5169,   score = 3.6096493766935667
# [CV]  colsample_bytree=1.0, learning_rate=0.5, score=-11.740658302874975, total=  56.2s
# [CV] colsample_bytree=1.0, learning_rate=0.2 .........................
# len = 1292,   score = 13.478885382841568
# len = 5169,   score = 3.5227210628841754
# [CV]  colsample_bytree=1.0, learning_rate=0.5, score=-13.478885382841568, total=  56.3s
# [CV] colsample_bytree=1.0, learning_rate=0.2 .........................
# len = 1292,   score = 12.924753023923941
# len = 1293,   score = 10.475497121420258
# len = 5169,   score = 3.60022995784345
# [CV]  colsample_bytree=1.0, learning_rate=0.5, score=-12.924753023923941, total=  52.4s
# [CV] colsample_bytree=1.0, learning_rate=0.2 .........................
# len = 5168,   score = 5.3155284176351145
# [CV]  colsample_bytree=1.0, learning_rate=0.2, score=-10.475497121420258, total=  52.4s
# [CV] colsample_bytree=1.0, learning_rate=0.2 .........................
# len = 1292,   score = 11.117034623969085
# len = 1292,   score = 10.834215885431947
# len = 5169,   score = 5.336422759488065
# [CV]  colsample_bytree=1.0, learning_rate=0.2, score=-11.117034623969085, total=  52.5s
# [CV] colsample_bytree=1.0, learning_rate=0.1 .........................
# len = 5169,   score = 5.2169555829976195
# [CV]  colsample_bytree=1.0, learning_rate=0.2, score=-10.834215885431947, total=  52.3s
# [CV] colsample_bytree=1.0, learning_rate=0.1 .........................
# len = 1292,   score = 12.739560703688749
# len = 5169,   score = 5.083671089095619
# [CV]  colsample_bytree=1.0, learning_rate=0.2, score=-12.739560703688749, total=  47.3s
# [CV] colsample_bytree=1.0, learning_rate=0.1 .........................
# len = 1292,   score = 11.720348640573915
# len = 5169,   score = 5.141228797655656
# [CV]  colsample_bytree=1.0, learning_rate=0.2, score=-11.720348640573915, total=  47.4s
# [CV] colsample_bytree=1.0, learning_rate=0.1 .........................
# len = 1293,   score = 10.28602423352988
# len = 5168,   score = 6.715778895080333
# [CV]  colsample_bytree=1.0, learning_rate=0.1, score=-10.28602423352988, total=  47.4s
# [CV] colsample_bytree=1.0, learning_rate=0.1 .........................
# len = 1292,   score = 10.713673464768195
# len = 5169,   score = 6.665321873525337
# [CV]  colsample_bytree=1.0, learning_rate=0.1, score=-10.713673464768195, total=  47.6s
# [CV] colsample_bytree=1.0, learning_rate=0.05 ........................
# len = 1292,   score = 10.721194890053104
# len = 5169,   score = 6.5247756812967745
# [CV]  colsample_bytree=1.0, learning_rate=0.1, score=-10.721194890053104, total=  46.8s
# len = 1292,   score = 12.356423250385728
# [CV] colsample_bytree=1.0, learning_rate=0.05 ........................
# len = 5169,   score = 6.357529378736886
# [CV]  colsample_bytree=1.0, learning_rate=0.1, score=-12.356423250385728, total=  46.7s
# [CV] colsample_bytree=1.0, learning_rate=0.05 ........................
# len = 1292,   score = 11.108216854559036
# len = 5169,   score = 6.545687264946997
# [CV]  colsample_bytree=1.0, learning_rate=0.1, score=-11.108216854559036, total=  46.7s
# [CV] colsample_bytree=1.0, learning_rate=0.05 ........................
# len = 1293,   score = 10.361952833966756
# len = 5168,   score = 7.906709202180556
# [CV]  colsample_bytree=1.0, learning_rate=0.05, score=-10.361952833966756, total=  46.8s
# [CV] colsample_bytree=1.0, learning_rate=0.05 ........................
# len = 1292,   score = 10.75734494287164
# len = 5169,   score = 7.902140926165771
# [CV]  colsample_bytree=1.0, learning_rate=0.05, score=-10.75734494287164, total=  47.6s
# len = 1292,   score = 10.641161956851285
# len = 5169,   score = 7.797123116446027
# [CV]  colsample_bytree=1.0, learning_rate=0.05, score=-10.641161956851285, total=  47.7s
# len = 1292,   score = 12.660080122397813
# len = 5169,   score = 7.4584930205879845
# [CV]  colsample_bytree=1.0, learning_rate=0.05, score=-12.660080122397813, total=  47.5s
# len = 1292,   score = 11.205167184589358
# len = 5169,   score = 7.738929479216408
# [CV]  colsample_bytree=1.0, learning_rate=0.05, score=-11.205167184589358, total=  47.4s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed: 17.7min finished
# Best Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.1}
# Best Score: -11.030268335919628
# elapsed time:  1089.884131502

# %%
params = {
    'n_estimators':500,
    'max_depth':3,
    'min_child_weight':2,
    'gamma':0.0,
    'subsample':0.9,
    'colsample_bytree':0.8,
    'learning_rate':0.1
}

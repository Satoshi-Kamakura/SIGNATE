# %% [markdown]
# # 年齢がある場合とない場合で、別々のモデルにしてみたらどうだろう？

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
train = pd.read_csv("data/train.tsv",delimiter="\t")

# %%
split_data = []
for did_survive in [0,1]:
    split_data.append(train[train.survived==did_survive])
temp = [i["age"].dropna() for i in split_data]
plt.hist(temp, histtype="barstacked", bins=16)
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)
# ([array([  8.,   6.,   2.,  32.,  39.,  29.,  23.,  21.,  19.,  12.,   2.,
#            7.,   4.,   2.,   0.,   0.]),
#   array([ 25.,   8.,   9.,  52.,  60.,  52.,  44.,  39.,  26.,  19.,   7.,
#           10.,   6.,   2.,   0.,   1.])],
#  array([  0.67    ,   5.628125,  10.58625 ,  15.544375,  20.5025  ,
#          25.460625,  30.41875 ,  35.376875,  40.335   ,  45.293125,
#          50.25125 ,  55.209375,  60.1675  ,  65.125625,  70.08375 ,
#          75.041875,  80.      ]),
#  <a list of 2 Lists of Patches objects>)

# %%
type(split_data)
# Out:
# list

# %%
type(split_data[0])
# Out:
# pandas.core.frame.DataFrame

# %%
type(train[train.survived==1])
# Out:
# pandas.core.frame.DataFrame

# %%
train.iloc[7].age
# Out:
# nan

# %%
type(train.iloc[7].age)
# Out:
# numpy.float64

# %%
np.isnan(train.iloc[7].age)
# Out:
# True

# %% [markdown]
# ### 年齢別の分類をループでやってみようとしたが………

# %%
for row in train.itertuples():
    if np.isnan(row.age):
        print(type(row))
        print (row)
        break
# Out:
# <class 'pandas.core.frame.Pandas'>
# Pandas(Index=7, id=19, survived=1, pclass=3, sex='female', age=nan, sibsp=0, parch=0, fare=7.2249999999999996, embarked='C')

# %%
with_age=pd.DataFrame()
without_age=pd.DataFrame()
for row in train.itertuples():
    if np.isnan(row.age):
        with_age.append(row)
    else:
        without_age.append(row)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-c793a7cb75f4> in <module>()
#       5         with_age.append(row)
#       6     else:
# ----> 7         without_age.append(row)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity)
#    4541         from pandas.core.reshape.concat import concat
#    4542         if isinstance(other, (list, tuple)):
# -> 4543             to_concat = [self] + other
#    4544         else:
#    4545             to_concat = [self, other]
#
# TypeError: can only concatenate list (not "Pandas") to list

# %% [markdown]
# ### 今度はgroupbyを使ってみる

# %%
t=train.groupby('survived')

# %%
t.head()
# Out:
#    id  survived  pclass     sex   age  sibsp  parch     fare embarked
# 0   3         1       1  female  35.0      1      0  53.1000        S
# 1   4         0       3    male  35.0      0      0   8.0500        S
# 2   7         0       3    male   2.0      3      1  21.0750        S
# 3   9         1       2  female  14.0      1      0  30.0708        C
# 4  11         1       1  female  58.0      0      0  26.5500        S
# 5  13         0       3    male  39.0      1      5  31.2750        S
# 6  16         0       3    male   2.0      4      1  29.1250        Q
# 7  19         1       3  female   NaN      0      0   7.2250        C
# 8  23         1       1    male  28.0      0      0  35.5000        S
# 9  24         0       3  female   8.0      3      1  21.0750        S

# %% [markdown]
# ### groupbyは集計だから用途に合わないや

# %% [markdown]
# ## boolの配列で対象の行を指定する→できた

# %%
type(train.iloc[7].age)
# Out:
# numpy.float64

# %%
nan=np.nan

# %%
np.isnan(train['age'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7       True
# 8      False
# 9      False
# 10     False
# 11      True
# 12      True
# 13      True
# 14      True
# 15     False
# 16      True
# 17     False
# 18      True
# 19     False
# 20     False
# 21      True
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 415    False
# 416    False
# 417    False
# 418    False
# 419    False
# 420    False
# 421    False
# 422     True
# 423    False
# 424     True
# 425    False
# 426    False
# 427    False
# 428    False
# 429    False
# 430    False
# 431    False
# 432    False
# 433     True
# 434    False
# 435    False
# 436     True
# 437    False
# 438    False
# 439    False
# 440    False
# 441    False
# 442    False
# 443    False
# 444     True
# Name: age, Length: 445, dtype: bool

# %%
train[np.isnan(train['age'])]
# Out:
#       id  survived  pclass     sex  age  sibsp  parch     fare embarked
# 7     19         1       3  female  NaN      0      0   7.2250        C
# 11    26         0       3    male  NaN      0      0   7.2250        C
# 12    28         1       3  female  NaN      0      0   7.8792        Q
# 13    29         0       3    male  NaN      0      0   7.8958        S
# 14    32         1       3  female  NaN      0      0   7.7500        Q
# 16    36         1       3    male  NaN      0      0   7.2292        C
# 18    42         0       3    male  NaN      0      0   7.8958        C
# 21    47         1       3  female  NaN      0      0   7.7500        Q
# 35    82         1       3  female  NaN      0      0   7.7875        Q
# 39    87         0       3    male  NaN      0      0   8.0500        S
# 44    95         0       3    male  NaN      0      0   8.0500        S
# 56   121         0       3    male  NaN      0      0   8.0500        S
# ...

# %%
train[np.isnan(train['age'])==False]
# Out:
#       id  survived  pclass     sex    age  sibsp  parch      fare embarked
# 0      3         1       1  female  35.00      1      0   53.1000        S
# 1      4         0       3    male  35.00      0      0    8.0500        S
# 2      7         0       3    male   2.00      3      1   21.0750        S
# 3      9         1       2  female  14.00      1      0   30.0708        C
# 4     11         1       1  female  58.00      0      0   26.5500        S
# 5     13         0       3    male  39.00      1      5   31.2750        S
# 6     16         0       3    male   2.00      4      1   29.1250        Q
# 8     23         1       1    male  28.00      0      0   35.5000        S
# 9     24         0       3  female   8.00      3      1   21.0750        S
# 10    25         1       3  female  38.00      1      5   31.3875        S
# 15    33         0       2    male  66.00      0      0   10.5000        S
# ...

# %%
train[np.isnan(train['age'])==False].survived.sum()/len(train[np.isnan(train['age'])==False])
# Out:
# 0.42777777777777776

# %%
train[np.isnan(train['age'])==True].survived.sum()/len(train[np.isnan(train['age'])==True])
# Out:
# 0.29411764705882354

# %% [markdown]
# ### ageがあると生存率42%、ないと生存率29%。

# %% [markdown]
# ### 別のモデルを作ってみることにする

# %% [markdown]
# 1. trainを年齢ありとなしのデータに分ける
# ２．　それぞれでロジスティック回帰モデルを作る
# ３．　testも年齢ありとなしのデータに分ける
# ４. 年齢ありとなし、それぞれで予測をする
# ５．　予測結果を連結して、IDで昇順ソートして提出データを作る

# %% [markdown]
# #### trainを年齢ありとなしのデータに分ける

# %%
without_age_train=train[np.isnan(train['age'])==True]
with_age_train=train[np.isnan(train['age'])==False]

# %%
with_age_y = with_age_train['survived']
without_age_y = without_age_train['survived']

# %%
with_age_train['embarked'].isnull().sum()
# Out:
# 2

# %%
without_age_train['embarked'].isnull().sum()
# Out:
# 0

# %%
with_age_train.groupby('embarked').describe()
# Out:
#             age                                                         fare  \
#           count       mean        std   min   25%   50%     75%   max  count
# embarked
# C          64.0  29.339844  14.260430  0.75  21.5  27.5  38.250  58.0   64.0
# Q          12.0  27.833333  15.006564  2.00  20.5  27.0  30.625  65.0   12.0
# S         282.0  29.093688  14.048043  0.67  20.0  28.0  37.000  80.0  282.0
#
#                     ...  sibsp      survived                                \
#                mean ...    75%  max    count      mean       std  min  25%
# embarked            ...
# C         67.040433 ...    1.0  2.0     64.0  0.625000  0.487950  0.0  0.0
# Q          9.839933 ...    0.0  4.0     12.0  0.333333  0.492366  0.0  0.0
# S         31.678072 ...    1.0  5.0    282.0  0.382979  0.486977  0.0  0.0
#
#
#           50%  75%  max
# embarked
# C         1.0  1.0  1.0
# Q         0.0  1.0  1.0
# S         0.0  1.0  1.0
#
# [3 rows x 56 columns]

# %%
with_age_train[(with_age_train['embarked']!='S')&(with_age_train['embarked']!='C')&(with_age_train['embarked']!='Q')]
# Out:
#       id  survived  pclass     sex   age  sibsp  parch  fare embarked
# 27    61         1       1  female  38.0      0      0  80.0      NaN
# 412  829         1       1  female  62.0      0      0  80.0      NaN

# %%
with_age_train['embarked'].fillna('S')
# Out:
# 0      S
# 1      S
# 2      S
# 3      C
# 4      S
# 5      S
# 6      Q
# 8      S
# 9      S
# 10     S
# 15     S
# 17     S
# 19     C
# 20     Q
# 22     S
# 23     S
# 24     C
# 25     S
# 26     S
# 27     S
# 28     S
# 29     S
# 30     S
# 31     S
# 32     S
# 33     C
# 34     S
# 36     S
# 37     S
# 38     S
#       ..
# 408    S
# 409    S
# 412    S
# 413    C
# 414    S
# 415    S
# 416    C
# 417    S
# 418    S
# 419    C
# 420    S
# 421    S
# 423    C
# 425    S
# 426    S
# 427    S
# 428    S
# 429    S
# 430    C
# 431    S
# 432    S
# 434    S
# 435    S
# 437    S
# 438    S
# 439    S
# 440    S
# 441    C
# 442    C
# 443    S
# Name: embarked, Length: 360, dtype: object

# %%
with_age_train['embarked'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ##### ダミー変数化しないといけなかった。

# %%
w = with_age_train
with_age_train=pd.concat([w[['pclass','age','sibsp','parch','fare']], pd.get_dummies(w['sex']),pd.get_dummies(w['embarked'])],axis=1)

# %%
w = without_age_train
without_age_train=pd.concat([w[['pclass','sibsp','parch','fare']], pd.get_dummies(w['sex']),pd.get_dummies(w['embarked'])],axis=1)

# %%
with_age_train.head(5)
# Out:
#    pclass   age  sibsp  parch     fare  female  male  C  Q  S
# 0       1  35.0      1      0  53.1000       1     0  0  0  1
# 1       3  35.0      0      0   8.0500       0     1  0  0  1
# 2       3   2.0      3      1  21.0750       0     1  0  0  1
# 3       2  14.0      1      0  30.0708       1     0  1  0  0
# 4       1  58.0      0      0  26.5500       1     0  0  0  1

# %%
without_age_train.head(5)
# Out:
#     pclass  age  sibsp  parch    fare  female  male  C  Q  S
# 7        3  NaN      0      0  7.2250       1     0  1  0  0
# 11       3  NaN      0      0  7.2250       0     1  1  0  0
# 12       3  NaN      0      0  7.8792       1     0  0  1  0
# 13       3  NaN      0      0  7.8958       0     1  0  0  1
# 14       3  NaN      0      0  7.7500       1     0  0  1  0

# %% [markdown]
# #### それぞれでモデルを作る

# %%
from sklearn.linear_model import LogisticRegression

# %%
with_age_model=LogisticRegression()
without_age_model=LogisticRegression()
with_age_model.fit(with_age_train, with_age_y)
without_age_model.fit(without_age_train,without_age_y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# Out:
# pclass     0
# age       85
# sibsp      0
# parch      0
# fare       0
# female     0
# male       0
# C          0
# Q          0
# S          0
# dtype: int64
